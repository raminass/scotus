# %% [markdown]
# # setup

# %%
# !pip install transformers==4.38.0 --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 26.3 MB/s eta 0:00:00

# %%
# !pip install datasets evaluate accelerate eyecite --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 24.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 15.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 20.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.7/147.7 kB 18.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 801.6/801.6 kB 17.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.7/110.7 kB 15.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.8/168.8 kB 23.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 25.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 66.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 47.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 13.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 33.1 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/projects/us_supreme_court
# Out:
# /content/drive/MyDrive/projects/us_supreme_court

# %%
from utils.pre_train import *
from utils.notebook_utils import *

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Read from Hub

# %%
import os
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
dataset = load_dataset("raminass/opinions-94-23")
opinions = pd.DataFrame(dataset["train"])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading readme:   0%|          | 0.00/457 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/116M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/4619 [00:00<?, ? examples/s]

# %%
opinions.author.value_counts()
# Out:
# Thomas        571
# Scalia        473
# Breyer        443
# Stevens       407
# Ginsburg      390
# Kennedy       326
# Alito         286
# Souter        230
# Sotomayor     226
# Gorsuch       168
# O'Connor      167
# Kavanaugh     160
# Kagan         145
# Rehnquist     144
# per_curiam    140
# Roberts       123
# Barrett       122
# Jackson        98
# Name: author, dtype: int64

# %% [markdown]
# # Filter Data

# %%
opinions=opinions[opinions.author!='per_curiam']

# %%
# opinions = opinions[~opinions.author.isin(['Jackson', 'Barrett'])] # 15 model
# opinions = opinions[~opinions.author.isin(['Jackson', 'Barrett', 'Kavanaugh'])] # 14 model

# %%
opinions.type.value_counts()
# Out:
# majority      2304
# dissenting    1327
# concurring     848
# Name: type, dtype: int64

# %%
opinions.author.value_counts()
# Out:
# Thomas       571
# Scalia       473
# Breyer       443
# Stevens      407
# Ginsburg     390
# Kennedy      326
# Alito        286
# Souter       230
# Sotomayor    226
# Gorsuch      168
# O'Connor     167
# Kavanaugh    160
# Kagan        145
# Rehnquist    144
# Roberts      123
# Barrett      122
# Jackson       98
# Name: author, dtype: int64

# %% [markdown]
# # Add Labels

# %%
id2label, label2id = get_labels_maping(opinions)

# %%
opinions["label"] = opinions["author"].map(label2id)

# %%
opinions.sample(3)
# Out:
#                          case_name  \
# 4153             Miller v. Alabama
# 2058  Puerto Rico v. Sanchez Valle
# 2895              Day v. McDonough
#
#                                                    text  year    author  \
# 4153  I join the Court’s opinion in full. I add that...  2012    Breyer
# 2058  I join in full the Court’s opinion, which coge...  2016  Ginsburg
# 2895  The Court today disregards the Federal Rules o...  2006    Scalia
#
#             type                                         clean_text  label
# 4153  concurring  I join the Court’s opinion in full. I add that...      5
# 2058  concurring  I join in full the Court’s opinion, which coge...     11
# 2895  dissenting  The Court today disregards the Federal Rules o...     12

# %%
import json
with open("data/j_year.json", "r") as j:
    judges_by_year = json.loads(j.read())
labels_by_year = {k: [label2id[item] for item in v] for k,v in judges_by_year.items()}

# %% [markdown]
# # Train-Test

# %%
from sklearn.model_selection import train_test_split
opinions_train, opinions_test = train_test_split(opinions, random_state=2024, test_size=0.2, stratify=opinions['label'])
# opinions_train, opinions_test = train_test_split(opinions, test_size=0.2, stratify=opinions['label'])

# %%
opinions_test.author.value_counts()
# Out:
# Thomas       114
# Scalia        95
# Breyer        89
# Stevens       81
# Ginsburg      78
# Kennedy       65
# Alito         57
# Souter        46
# Sotomayor     45
# Gorsuch       34
# O'Connor      33
# Kavanaugh     32
# Rehnquist     29
# Kagan         29
# Roberts       25
# Barrett       24
# Jackson       20
# Name: author, dtype: int64

# %%
opinions_train.author.value_counts()
# Out:
# Thomas       457
# Scalia       378
# Breyer       354
# Stevens      326
# Ginsburg     312
# Kennedy      261
# Alito        229
# Souter       184
# Sotomayor    181
# O'Connor     134
# Gorsuch      134
# Kavanaugh    128
# Kagan        116
# Rehnquist    115
# Roberts       98
# Barrett       98
# Jackson       78
# Name: author, dtype: int64

# %% [markdown]
# # Split Paragraphs

# %%
par_train = split_data(opinions_train, id2label, label2id)
par_test = split_data(opinions_test, id2label, label2id)

# %%
par_train.author.value_counts()
# Out:
# Thomas       3998
# Breyer       3420
# Scalia       3334
# Kennedy      3072
# Alito        2920
# Ginsburg     2833
# Stevens      2271
# Sotomayor    2037
# Souter       1750
# Kagan        1542
# O'Connor     1296
# Jackson      1214
# Gorsuch      1206
# Roberts      1124
# Kavanaugh    1100
# Rehnquist     848
# Barrett       745
# Name: author, dtype: int64

# %%
par_test.author.value_counts()
# Out:
# Breyer       960
# Thomas       941
# Kennedy      910
# Ginsburg     756
# Scalia       751
# Alito        662
# Stevens      569
# Sotomayor    496
# Souter       466
# Kagan        371
# O'Connor     365
# Gorsuch      352
# Roberts      327
# Kavanaugh    275
# Rehnquist    237
# Jackson      220
# Barrett      176
# Name: author, dtype: int64

# %%
# par_train = par_train.groupby('author',as_index = False,group_keys=False).apply(lambda s: s.sample(2000, replace=len(s)<2000))

# %%
par_train.author.value_counts()
# Out:
# Thomas       3998
# Breyer       3420
# Scalia       3334
# Kennedy      3072
# Alito        2920
# Ginsburg     2833
# Stevens      2271
# Sotomayor    2037
# Souter       1750
# Kagan        1542
# O'Connor     1296
# Jackson      1214
# Gorsuch      1206
# Roberts      1124
# Kavanaugh    1100
# Rehnquist     848
# Barrett       745
# Name: author, dtype: int64

# %%
# par_test = par_test.groupby('author',as_index = False,group_keys=False).apply(lambda s: s.sample(400, replace=len(s)<400))

# %%
par_test.author.value_counts()
# Out:
# Breyer       960
# Thomas       941
# Kennedy      910
# Ginsburg     756
# Scalia       751
# Alito        662
# Stevens      569
# Sotomayor    496
# Souter       466
# Kagan        371
# O'Connor     365
# Gorsuch      352
# Roberts      327
# Kavanaugh    275
# Rehnquist    237
# Jackson      220
# Barrett      176
# Name: author, dtype: int64

# %% [markdown]
# # Model

# %%
from utils import train
from transformers import set_seed
set_seed(1002)
# Out:
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]

# %%
from datasets.utils.logging import disable_progress_bar
disable_progress_bar()
ds_dict = {
        "train": Dataset.from_pandas(
            par_train[["label", "text"]], preserve_index=False
        ),
        "test": Dataset.from_pandas(
            par_test[["label", "text"]], preserve_index=False
        ),
    }
ds = DatasetDict(ds_dict)
tokenized_court = train.tokenize_dataset(ds)

# %%
 trainer = train.get_trainer(
        id2label,
        label2id,
        tokenized_court,
        epochs=3,
        model_name=f"M2",
        batch_size=16,
        push_to_hub=True,
    )
trainer.train()
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at raminass/scotus-v10 and are newly initialized because the shapes did not match:
# - classifier.weight: found shape torch.Size([13, 512]) in the checkpoint and torch.Size([17, 512]) in the model instantiated
# - classifier.bias: found shape torch.Size([13]) in the checkpoint and torch.Size([17]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:432: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(
#     <div>
#
#       <progress value='6510' max='6510' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6510/6510 48:09, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.809200</td>
#       <td>1.008980</td>
#       <td>0.704777</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.450400</td>
#       <td>0.965925</td>
#       <td>0.730134</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.273600</td>
#       <td>0.938778</td>
#       <td>0.747340</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=6510, training_loss=0.6472735933078233, metrics={'train_runtime': 2891.7012, 'train_samples_per_second': 36.01, 'train_steps_per_second': 2.251, 'total_flos': 6137584409548800.0, 'train_loss': 0.6472735933078233, 'epoch': 3.0})

# %%
trainer.push_to_hub()
# Out:
# CommitInfo(commit_url='https://huggingface.co/raminass/M2/commit/1e627561a272b6fdd99d341a3ee084ac9473c67a', commit_message='End of training', commit_description='', oid='1e627561a272b6fdd99d341a3ee084ac9473c67a', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# # Analysis

# %%
from scipy.special import softmax
pred = []
for index, row in opinions_test.iterrows():
  chunks = split_text(row["clean_text"])
  list_ds = [{"text":c} for c in chunks]
  tokenized_case = train.tokenize_dataset(Dataset.from_list(list_ds))
  predictions = trainer.predict(tokenized_case)
  pred.append(predictions)

# %%
res = []
i = 0
for index, row in opinions_test.iterrows():
  avg = softmax(pred[i].predictions, axis=1).mean(axis=0)
  res.append(np.argmax(avg))
  i+=1
(res == opinions_test['label']).mean()
# Out:
# 0.9084821428571429

# %%
from utils import metrics

# %%
metrics.plot_confusion(opinions_test['label'],res, label2id)

# %%
metrics.print_metrics(opinions_test['author'],[id2label[i] for i in res])
# Out:
# -------------------- Key Metrics --------------------
#
# Accuracy: 0.91
# Balanced Accuracy: 0.90
#
# Micro Precision: 0.91
# Micro Recall: 0.91
# Micro F1-score: 0.91
#
# Macro Precision: 0.90
# Macro Recall: 0.90
# Macro F1-score: 0.90
#
# Weighted Precision: 0.91
# Weighted Recall: 0.91
# Weighted F1-score: 0.91
#
# --------------- Classification Report ---------------
#
#               precision    recall  f1-score   support
#
#        Alito       0.87      0.95      0.91        57
#      Barrett       0.79      0.62      0.70        24
#       Breyer       0.94      0.94      0.94        89
#     Ginsburg       1.00      0.91      0.95        78
#      Gorsuch       0.94      0.91      0.93        34
#      Jackson       0.95      1.00      0.98        20
#        Kagan       0.94      1.00      0.97        29
#    Kavanaugh       0.81      0.69      0.75        32
#      Kennedy       1.00      0.92      0.96        65
#     O'Connor       0.86      0.94      0.90        33
#    Rehnquist       0.88      1.00      0.94        29
#      Roberts       0.91      0.80      0.85        25
#       Scalia       0.98      0.94      0.96        95
#    Sotomayor       0.77      0.96      0.85        45
#       Souter       1.00      0.91      0.95        46
#      Stevens       0.84      0.94      0.89        81
#       Thomas       0.87      0.86      0.86       114
#
#     accuracy                           0.91       896
#    macro avg       0.90      0.90      0.90       896
# weighted avg       0.91      0.91      0.91       896

# %%
list_test = [{"text":c} for c in par_test.text]
tokenized_case = train.tokenize_dataset(Dataset.from_list(list_test))
par_model_pred = trainer.predict(tokenized_case)
l = par_model_pred.predictions.argmax(axis=1)

# %%
metrics.plot_confusion(par_test['label'],l, label2id)

# %%
metrics.print_metrics(par_test['author'],[id2label[i] for i in l])
# Out:
# -------------------- Key Metrics --------------------
#
# Accuracy: 0.75
# Balanced Accuracy: 0.74
#
# Micro Precision: 0.75
# Micro Recall: 0.75
# Micro F1-score: 0.75
#
# Macro Precision: 0.75
# Macro Recall: 0.74
# Macro F1-score: 0.74
#
# Weighted Precision: 0.77
# Weighted Recall: 0.75
# Weighted F1-score: 0.75
#
# --------------- Classification Report ---------------
#
#               precision    recall  f1-score   support
#
#        Alito       0.68      0.79      0.73       662
#      Barrett       0.56      0.61      0.58       176
#       Breyer       0.92      0.81      0.86       960
#     Ginsburg       0.94      0.79      0.86       756
#      Gorsuch       0.80      0.71      0.75       352
#      Jackson       0.87      0.97      0.91       220
#        Kagan       0.92      0.87      0.89       371
#    Kavanaugh       0.66      0.68      0.67       275
#      Kennedy       0.86      0.76      0.81       910
#     O'Connor       0.66      0.48      0.56       365
#    Rehnquist       0.57      0.69      0.63       237
#      Roberts       0.75      0.65      0.69       327
#       Scalia       0.71      0.73      0.72       751
#    Sotomayor       0.74      0.84      0.79       496
#       Souter       0.91      0.65      0.76       466
#      Stevens       0.52      0.84      0.64       569
#       Thomas       0.65      0.68      0.67       941
#
#     accuracy                           0.75      8834
#    macro avg       0.75      0.74      0.74      8834
# weighted avg       0.77      0.75      0.75      8834
